# %%
# notebooks/example_notebook.ipynb

import sys
import os
sys.path.append(os.path.abspath('../scripts'))

# %%
from database import connect_to_db
from user_overview import analyze_top_handsets, analyze_top_manufacturers
from analysis import univariate_analysis

# %%
# Connect to the database
engine = connect_to_db()
# Out:
# Database connection successful!

# %%
# Fetch and analyze handsets
handsets = analyze_top_handsets(engine)
univariate_analysis(handsets, "count", plot_type="hist", title="Top Handsets", xlabel="Count", ylabel="Frequency")
# Out:
# Query executed successfully!

# %%
# Fetch and analyze manufacturers
manufacturers = analyze_top_manufacturers(engine)
univariate_analysis(manufacturers, "count", plot_type="hist", title="Top Manufacturers", xlabel="Count", ylabel="Frequency")
# Out:
# Query executed successfully!
